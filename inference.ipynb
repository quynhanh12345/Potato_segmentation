# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/mmseg
# Out:
# /content/drive/MyDrive/mmseg

# %%
# !ls
# Out:
# inference.ipynb  mmsegmentation  test  train.ipynb  Untitled1.ipynb

# %%
# !pip3 install openmim
# !mim install mmcv-full
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for openmim: filename=openmim-0.1.5-py2.py3-none-any.whl size=42503 sha256=038cfc28abe9a858277e429526f4f6f0e2e94ecf7addc2d4983a24836150a503
#   Stored in directory: /root/.cache/pip/wheels/16/8b/e1/bdebbbc687aa50224a5ce46fe97a040a0c59f92b34bfc750b6
# Successfully built openmim
# ...
# installing mmcv-full from wheel.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.11.0/index.html
# ...
#      |████████████████████████████████| 37.5 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 190 kB 5.0 MB/s
# ...

# %%
import mmcv

# %%
# %cd /content/drive/MyDrive/mmseg/mmsegmentation
import mmseg
# Out:
# /content/drive/MyDrive/mmseg/mmsegmentation

# %%
from mmseg.apis.inference import inference_segmentor, init_segmentor, show_result_pyplot
from mmseg.core.evaluation import get_palette

# %%
config_file = '/content/drive/MyDrive/mmseg/mmsegmentation/configs/potato_cfg.py'
checkpoint_file = '/content/drive/MyDrive/mmseg/mmsegmentation/work_dirs/tutorial/latest.pth'

# %%
# !python /content/drive/MyDrive/mmseg/mmsegmentation/mmseg/apis/inference.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/mmseg/mmsegmentation/mmseg/apis/inference.py", line 8, in <module>
#     from mmseg.datasets.pipelines import Compose
# ModuleNotFoundError: No module named 'mmseg'

# %%
model = init_segmentor(config_file, checkpoint_file, device='cuda:0')
print(model)
# Out:
# 99999
# config
# 3333333333333333
# 5555555
# /content/drive/MyDrive/mmseg/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 3333333333333333
# ...

# %%
print(dir(model))
# Out:
# ['CLASSES', 'PALETTE', 'T_destination', '__abstractmethods__', '__annotations__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_apply', '_auxiliary_head_forward_train', '_backward_hooks', '_buffers', '_call_impl', '_decode_head_forward_test', '_decode_head_forward_train', '_dump_init_info', '_forward_hooks', '_forward_pre_hooks', '_get_backward_hooks', '_get_name', '_init_auxiliary_head', '_init_decode_head', '_is_full_backward_hook', '_is_init', '_load_from_state_dict', '_load_state_dict_pre_hooks', '_maybe_warn_non_full_backward_hook', '_modules', '_named_members', '_non_persistent_buffers_set', '_parameters', '_parse_losses', '_reg
# ...

# %%
img = '/content/drive/MyDrive/mmseg/test/2_NG_SET1_IBUTSU1_00031_bmp.rf.b4774e880a66fb722e3d309979c4308a.jpg'
result = inference_segmentor(model, img)
palette = [[128, 128, 128], [241, 134, 51]]
show_result_pyplot(model, img, result, palette)
# Out:
# [[128, 128, 128], [241, 134, 51]]
# /content/drive/MyDrive/mmseg/mmsegmentation/mmseg/models/segmentors/base.py:289: UserWarning: show==False and out_file is not specified, only result image will be returned
#   warnings.warn('show==False and out_file is not specified, only '

# %%
# !mkdir result_segment

# %%
# !mkdir Ф▓ВпВ─ВвВ╚ВвПєС╘

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВщПєС╘

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/NG

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET 1

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET2

# %%
# !mkdir /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET3

# %%
# %cd /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET1
# Out:
# /content/drive/MyDrive/mmseg/mmsegmentation/result_segment/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET1

# %%
img = '/content/drive/MyDrive/Dataset/Ф▓ВпВ─ВвВ╚ВвПєС╘/OK/test/SET3/OK_SET3_00033.bmp'
result = inference_segmentor(model, img)
palette = [[128, 128, 128], [241, 134, 51]]
show_result_pyplot(model, img, result, palette, out_file='/content/drive/MyDrive/mmseg/mmsegmentation/result_segment/1/OK/test/SET2/OK_SET2_00033.bmp')
# Out:
# [[128, 128, 128], [241, 134, 51]]
# /content/drive/MyDrive/mmseg/mmsegmentation/mmseg/models/segmentors/base.py:289: UserWarning: show==False and out_file is not specified, only result image will be returned
#   warnings.warn('show==False and out_file is not specified, only '
